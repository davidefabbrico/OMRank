# %% [markdown]
# # Optimal metrics on the space of rankings for Social Choice Theory

# %% [markdown]
# ### Francesco Colasanto & Davide Fabbrico

# %% [markdown]
# The analysis of properties of Social Function is focal point of Social Choice Theory. In the Arrow's framework there is a group of individuals who has to choose among a set $\{1,..., k\} =: A_k$ of alternatives. Each individual gives his vote through a linear order on $A_k$. A Social Function takes as input an electoral profile and returns the winner alternatives. There is a large class of Social Functions that can be defined starting from a "metric" on the space of rankings $L(A_k)$ with alternatives $A_k$, for instance the Kemeny's Social Preference Function, the Score Social Choice Functions as the Plurality or the Borda's one.

# %%
import numpy as np
import math
import itertools
from functools import lru_cache
from sympy.combinatorics import Permutation
from tqdm import tqdm


class EfficientPermutationProcessor:
    def __init__(self, k):
        self.k = k
        self.rank_dict = {}
        self.perm_list = []

        for idx, perm in enumerate(itertools.permutations(range(k))):
            self.perm_list.append(perm)
            self.rank_dict[perm] = idx

        # Precomputa l'intera tavola di moltiplicazione (fact x fact)
        self._build_mult_table()

    def _build_mult_table(self):
        fact = self.fact
        self.mult_table = np.zeros((fact, fact), dtype=np.int32)
        for i in range(fact):
            for j in range(fact):
                self.mult_table[i, j] = self.perm_product(i, j)

    @property
    def fact(self):
        return math.factorial(self.k)

    @lru_cache(maxsize=None)
    def perm_product(self, i, j):
        p1 = Permutation(list(self.perm_list[i]))
        p2 = Permutation(list(self.perm_list[j]))
        product = p1 * p2
        return self.rank_dict[tuple(product.array_form)]


class SimplexPSO:
    def __init__(self, n_particles, dim, objective_func, objective_params,
                 max_iter=100, fixed_first=None):
        self.n_particles = n_particles
        self.dim = dim
        self.objective_func = objective_func
        self.objective_params = objective_params
        self.max_iter = max_iter
        self.fixed_first = fixed_first

        self.omega = 0.9
        self.c1 = 2.0
        self.c2 = 2.0

        if fixed_first is not None:
            free_dim = dim - 1
            remaining = 1.0 - fixed_first
            self.positions = np.random.dirichlet(np.ones(free_dim),
                                                  size=n_particles) * remaining
        else:
            self.positions = np.random.dirichlet(np.ones(dim), size=n_particles)

        self.velocities = np.zeros_like(self.positions)
        self.initialize_best_positions()

    def _build_full_vector(self, x):
        """Ricostruisce il vettore completo inserendo fixed_first in posizione 0."""
        if self.fixed_first is not None:
            return np.concatenate([[self.fixed_first], x])
        return x

    def initialize_best_positions(self):
        self.pbest = self.positions.copy()
        self.pbest_scores = np.array([
            self.objective_func(self._build_full_vector(p), **self.objective_params)
            for p in self.positions
        ])
        best_idx = np.argmin(self.pbest_scores)
        self.gbest = self.pbest[best_idx]
        self.gbest_score = self.pbest_scores[best_idx]

    def project_simplex(self, x, target_sum=1.0):
        """Proietta su simplesso con somma target_sum invece di 1."""
        x_scaled = x / target_sum
        x_sorted = np.sort(x_scaled)[::-1]
        cumsum = np.cumsum(x_sorted) - 1.0
        indices = np.arange(1, len(x_scaled) + 1)
        rho = np.where(x_sorted - cumsum / indices > 0)[0][-1]
        lambda_ = cumsum[rho] / (rho + 1)
        return np.maximum(x_scaled - lambda_, 0) * target_sum

    def update_particle(self, idx):
        r1, r2 = np.random.rand(2)
        self.velocities[idx] = (self.omega * self.velocities[idx] +
                                self.c1 * r1 * (self.pbest[idx] - self.positions[idx]) +
                                self.c2 * r2 * (self.gbest - self.positions[idx]))

        target_sum = 1.0 - self.fixed_first if self.fixed_first is not None else 1.0
        new_pos = self.project_simplex(self.positions[idx] + self.velocities[idx],
                                        target_sum)
        self.positions[idx] = new_pos
        score = self.objective_func(self._build_full_vector(new_pos),
                                     **self.objective_params)

        if score < self.pbest_scores[idx]:
            self.pbest[idx] = new_pos
            self.pbest_scores[idx] = score
            if score < self.gbest_score:
                self.gbest = new_pos
                self.gbest_score = score

    def optimize(self):
        convergence = []
        for _ in tqdm(range(self.max_iter)):
            for i in range(self.n_particles):
                self.update_particle(i)
            self.update_inertia()
            convergence.append(self.gbest_score)
        return self._build_full_vector(self.gbest), self.gbest_score, convergence

    def update_inertia(self):
        self.omega *= 0.99


def sparse_preference(vector, processor, n=500, MCiterations=100, eps=0.05):
    fact = processor.fact
    vector = np.asarray(vector)
    mult_table = processor.mult_table  # shape (fact, fact)
    counts = []

    for _ in range(MCiterations):
        samples = np.random.choice(fact, n)

        # mult_table[:, samples] ha shape (fact, n)
        # vector[mult_table[:, samples]] ha shape (fact, n)
        # sum su axis=1 -> shape (fact,)
        all_sums = vector[mult_table[:, samples]].sum(axis=1)

        current_min = all_sums.min()
        eps_value = eps * abs(current_min)
        counts.append(np.sum(
            (all_sums >= current_min - eps_value) &
            (all_sums <= current_min + eps_value)
        ))

    return np.mean(counts)


def dynamic_choice(vector, processor, n=500, MCiterations=100, eps=0.05):
    k = processor.k
    vector = np.asarray(vector)
    counts = []

    for _ in range(MCiterations):
        # Campiona n permutazioni in una volta -> shape (n, k)
        perms = np.argsort(np.random.rand(n, k), axis=1)

        # vector[perms] ha shape (n, k)
        # sum su axis=0 -> sums ha shape (k,)
        sums = vector[perms].sum(axis=0)

        min_sum = sums.min()
        eps_value = eps * abs(min_sum)
        counts.append(np.sum(
            (sums >= min_sum - eps_value) &
            (sums <= min_sum + eps_value)
        ))

    return np.mean(counts)

# %%
if __name__ == "__main__":
    k = 3  
    n = 10
    
    # # Configurazione per Preference
    # pso_pref = SimplexPSO(
    #     n_particles=100,
    #     dim=math.factorial(k) - 1,
    #     objective_func=sparse_preference,
    #     objective_params={'processor': EfficientPermutationProcessor(k), 'n': n},
    #     max_iter=50,
    #     fixed_first=0.0 
    # )
    
    # Configurazione per Choice
    pso_choice = SimplexPSO(
        n_particles=100,
        dim=k,
        objective_func=dynamic_choice,
        objective_params={'processor': EfficientPermutationProcessor(k), 'n': n},
        max_iter=50,
        fixed_first=0.0 
    )
    
    # Esegui ottimizzazioni
    # best_pref, score_pref, _ = pso_pref.optimize()
    best_choice, score_choice, _ = pso_choice.optimize()
    
    # print(f"Preference Score: {score_pref:.4f}")
    print(f"Choice Score: {score_choice:.4f}")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 24.55it/s]
# Choice Score: 1.0000

# %%
import numpy as np
import pandas as pd
import time
import math
import itertools

# Parametri simulazione
ks = [3, 5, 8]
ns = [10, 100, 1000]
epsilons = [0.1, 0.3, 0.5]
n_particles = 50
max_iter = 50
n_repeats = 5

# Inizializza raccolta risultati
all_results = []

# Loop su tutte le combinazioni (k, n, eps) con ripetizioni
for k, n, eps in itertools.product(ks, ns, epsilons):
    print(f"\n--- Simulazione per k={k}, n={n}, eps={eps} ---")
    
    for repeat in range(1, n_repeats + 1):
        print(f" Ripetizione {repeat}")
        processor = EfficientPermutationProcessor(k)

        # Define wrapped objective functions
        objective_pref = lambda v, n=n, eps=eps: sparse_preference(v, processor=processor, n=n, eps=eps)
        objective_choice = lambda v, n=n, eps=eps: dynamic_choice(v, processor=processor, n=n, eps=eps)

        # Dimensionalità
        dim_pref = math.factorial(k)
        dim_choice = k

        # Ottimizzazione preference
        start = time.time()
        pso_pref = SimplexPSO(n_particles, dim_pref, objective_pref, {}, max_iter, fixed_first=0.0)
        best_p, score_p, _ = pso_pref.optimize()
        time_pref = time.time() - start

        # Ottimizzazione choice
        start = time.time()
        pso_choice = SimplexPSO(n_particles, dim_choice, objective_choice, {}, max_iter, fixed_first=0.0)
        best_c, score_c, _ = pso_choice.optimize()
        time_choice = time.time() - start

        # Aggiungi risultato
        all_results.append({
            'k': k,
            'n': n,
            'eps': eps,
            'repeat': repeat,
            'score_pref': score_p,
            'score_choice': score_c,
            'time_pref': time_pref,
            'time_choice': time_choice
        })

# Salvataggio in CSV
df = pd.DataFrame(all_results)
df.to_csv("risultati_simulazione_pso.csv", index=False)
print("Simulazione completata e salvata in 'risultati_simulazione_pso.csv'")
# Out:
# --- Simulazione per k=3, n=10, eps=0.1 ---
#  Ripetizione 1
# 100%|███████████████████████████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 25.22it/s]
#  62%|███████████████████████████████████████████████████▍                               | 31/50 [00:00<00:00, 49.03it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 43
#      41 start = time.time()
#      42 pso_choice = SimplexPSO(n_particles, dim_choice, objective_choice, {}, max_iter, fixed_first=0.0)
# ---> 43 best_c, score_c, _ = pso_choice.optimize()
#      44 time_choice = time.time() - start
#      46 # Aggiungi risultato
#
# Cell In[29], line 116, in SimplexPSO.optimize(self)
#     114 for _ in tqdm(range(self.max_iter)):
#     115     for i in range(self.n_particles):
# --> 116         self.update_particle(i)
#     117     self.update_inertia()
#     118     convergence.append(self.gbest_score)
#
# Cell In[29], line 102, in SimplexPSO.update_particle(self, idx)
#      99 new_pos = self.project_simplex(self.positions[idx] + self.velocities[idx],
#     100                                 target_sum)
#     101 self.positions[idx] = new_pos
# --> 102 score = self.objective_func(self._build_full_vector(new_pos),
#     103                              **self.objective_params)
#     105 if score < self.pbest_scores[idx]:
#     106     self.pbest[idx] = new_pos
#
# Cell In[31], line 28, in <lambda>(v, n, eps)
#      26 # Define wrapped objective functions
#      27 objective_pref = lambda v, n=n, eps=eps: sparse_preference(v, processor=processor, n=n, eps=eps)
# ---> 28 objective_choice = lambda v, n=n, eps=eps: dynamic_choice(v, processor=processor, n=n, eps=eps)
#      30 # Dimensionalità
#      31 dim_pref = math.factorial(k)
#
# Cell In[29], line 156, in dynamic_choice(vector, processor, n, MCiterations, eps)
#     152 counts = []
#     154 for _ in range(MCiterations):
#     155     # Campiona n permutazioni in una volta -> shape (n, k)
# --> 156     perms = np.argsort(np.random.rand(n, k), axis=1)
#     158     # vector[perms] ha shape (n, k)
#     159     # sum su axis=0 -> sums ha shape (k,)
#     160     sums = vector[perms].sum(axis=0)
#
# KeyboardInterrupt:
